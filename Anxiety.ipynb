# %% [markdown]
# <a href="https://colab.research.google.com/github/Abash05/Kaggle-Team-1---Digital-Habits-and-Mental-Health/blob/AidanAnxietyNew/Anxiety.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

from google.colab import files

# Upload Data.csv
files.upload()
# Out:
#      <input type="file" id="files-4ee7dbd8-678a-4291-bd09-730062ed473b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ee7dbd8-678a-4291-bd09-730062ed473b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Set df to datset
df = pd.read_csv("Data.csv")

# Display basic info
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (3500, 24)
#    id  age  gender         region income_level education_level  \
# 0   1   40  Female           Asia         High     High School
# 1   2   27    Male         Africa    Lower-Mid          Master
# 2   3   31    Male  North America    Lower-Mid        Bachelor
# 3   4   41  Female    Middle East          Low          Master
# 4   5   26  Female         Europe    Lower-Mid        Bachelor
#
#            daily_role  device_hours_per_day  phone_unlocks  \
# 0     Part-time/Shift                  3.54             45
# 1  Full-time Employee                  5.65            100
# 2  Full-time Employee                  8.87            181
# 3      Caregiver/Home                  4.05             94
# 4  Full-time Employee                 13.07            199
#
#    notifications_per_day  ...  sleep_quality  anxiety_score  depression_score  \
# 0                    561  ...       3.353627       9.926651               5.0
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['anxiety_score'], bins=20, kde=True, palette='coolwarm')
plt.title('Distribution of Anxiety Score', fontsize=14, fontweight='bold')
plt.xlabel('Anxiety Score')
plt.ylabel('Frequency')
plt.grid(alpha=0.3)
plt.show()
# Out:
# /tmp/ipython-input-488155932.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['anxiety_score'], bins=20, kde=True, palette='coolwarm')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='gender', y='anxiety_score', data=df, palette='pastel')
plt.title("Anxiety Score by Gender")
plt.show()
# Out:
# /tmp/ipython-input-4008928197.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='anxiety_score', data=df, palette='pastel')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='income_level', y='anxiety_score', data=df, palette='cool')
plt.title("Anxiety Score by Income Level")
plt.show()
# Out:
# /tmp/ipython-input-2375277501.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='income_level', y='anxiety_score', data=df, palette='cool')

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='education_level', y='anxiety_score', data=df, palette='mako')
plt.title("Anxiety Score by Education Level")
plt.show()
# Out:
# /tmp/ipython-input-2706354367.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='education_level', y='anxiety_score', data=df, palette='mako')

# %%
sns.boxplot(
    data=df,
    x='high_risk_flag',
    y='anxiety_score',
    palette="Set1",
    showfliers=False
)
plt.title("Anxiety Score by High Risk Flag", fontsize=14, fontweight="bold")
plt.xlabel("High Risk Flag")
plt.ylabel("Anxiety Score")
plt.grid(alpha=0.3)
plt.show()
# Out:
# /tmp/ipython-input-524190986.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
sns.scatterplot(
    data=df,
    x='anxiety_score',
    y='productivity_score',
    alpha=0.5
)
sns.regplot(
    data=df,
    x='anxiety_score',
    y='productivity_score',
    scatter=False,
    color='red',
    line_kws={"lw": 2}
)
plt.title("Relationship between Anxiety Score and Productivity Score", fontsize=14, fontweight="bold")
plt.xlabel("Anxiety Score")
plt.ylabel("Productivity Score")
plt.grid(alpha=0.3)
plt.show()

# %%
sns.scatterplot(
    data=df,
    x='anxiety_score',
    y='digital_dependence_score',
    alpha=0.5
)
sns.regplot(
    data=df,
    x='anxiety_score',
    y='digital_dependence_score',
    scatter=False,
    color='red',
    line_kws={"lw": 2}
)
plt.title("Relationship between Anxiety Score and Dependence Score", fontsize=14, fontweight="bold")
plt.xlabel("Anxiety Score")
plt.ylabel("Dependence Score")
plt.grid(alpha=0.3)
plt.show()
